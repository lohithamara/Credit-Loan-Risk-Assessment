# %%
import pandas as pd

# %%
df=pd.read_csv("accepted_2007_to_2018Q4.csv",usecols=["loan_amnt","term","int_rate","installment","grade","sub_grade","purpose","emp_length","annual_inc","verification_status","home_ownership","fico_range_low","earliest_cr_line","delinq_2yrs","pub_rec","dti","revol_bal","revol_util","bc_util","issue_d","application_type","loan_status","recoveries"])

# %%
df.shape
# Out:
# (327707, 23)

# %%
df.sample(5)
# Out:
#         loan_amnt        term  int_rate  installment grade sub_grade  \
# 196640    20000.0   36 months      9.99       645.25     B        B3
# 28561      3000.0   36 months     16.55       106.29     D        D2
# 262917    27000.0   36 months     11.53       890.74     B        B5
# 174006     7500.0   36 months     14.65       258.71     C        C5
# 147712     4625.0   36 months     19.99       171.86     E        E4
#
#        emp_length home_ownership  annual_inc verification_status  ...    dti  \
# 196640   < 1 year       MORTGAGE     80000.0     Source Verified  ...  13.71
# 28561         NaN            OWN     10874.0            Verified  ...  30.68
# 262917        NaN           RENT     90250.0     Source Verified  ...   7.42
# 174006    6 years            OWN     32000.0     Source Verified  ...  23.93
# 147712    2 years       MORTGAGE     55000.0            Verified  ...  26.45
#
#        delinq_2yrs earliest_cr_line  fico_range_low  pub_rec revol_bal  \
# 196640         0.0         Oct-1993           660.0      1.0   11913.0
# 28561          0.0         May-2008           665.0      0.0    2968.0
# 262917         0.0         Dec-1998           720.0      0.0   10019.0
# 174006         0.0         Nov-2011           700.0      0.0    4442.0
# 147712         0.0         Apr-2001           680.0      0.0   31848.0
#
#         revol_util  recoveries  application_type  bc_util
# 196640        49.8        0.00        Individual     31.8
# 28561         58.2      272.34        Individual     38.5
# 262917        53.3        0.00        Individual     77.1
# 174006        28.3        0.00        Individual     38.6
# 147712        55.1      885.76        Individual     93.8
#
# [5 rows x 23 columns]

# %%
df['loan_status'].value_counts()
# Out:
# loan_status
# Fully Paid            231966
# Charged Off            58623
# Current                35224
# Late (31-120 days)      1149
# In Grace Period          514
# Late (16-30 days)        230
# Default                    1
# Name: count, dtype: int64

# %%
df = df[df['loan_status'].isin(['Fully Paid', 'Charged Off'])]

# %%
df.shape
# Out:
# (290589, 23)

# %%
df['loan_status'].value_counts()
# Out:
# loan_status
# Fully Paid     231966
# Charged Off     58623
# Name: count, dtype: int64

# %%
df.to_csv("required_dataset")
